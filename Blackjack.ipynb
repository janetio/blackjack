# %%
suits = ['Hearts', 'Clubs', 'Spades','Diamonds']
ranks = ['Ace','Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', 'Ten', 'Jack', 'Queen', 'King']
values = {'Ace':11, 'Two':2,'Three':3,'Four':4,'Five':5,'Six':6,'Seven':7,'Eight':8,'Nine':9,'Ten':10,'Jack':10,'Queen':10,'King':10}

# %%
class Card:
    def __init__(self, suit, rank):
        self.suit=suit
        self.rank=rank
        self.value=values[rank]
    
    def __str__(self):
        return f'{self.rank} of {self.suit}'

# %%
class Deck:
    def __init__(self):
        self.all_cards=[]
        for suit in suits:
            for rank in ranks:
                self.all_cards.append(Card(suit, rank))
    
    def shuffle(self):
        shuffle(self.all_cards)
    
    def dealone(self):
        return self.all_cards.pop()

# %%
import random

# %%
from random import shuffle

# %%
class Hand:
    def __init__(self):
        self.cards = []  
        self.value = 0   
        self.aces = 0   
    
    def add_card(self,card):
        self.cards.append(card)
        self.value += values[card.rank]
        if card.rank =="Ace":
            self.aces +=1
    
    def adjust_for_ace(self):
        for num in range(self.aces):
            self.value -=10

# %%
class Chips:
    
    def __init__(self):
        self.total = int(input('How many chips do you want to start with?'))  
        self.bet=int(input('How much do you want to bet?'))
        
    def win_bet(self):
        self.total += self.bet*2
    
    def lose_bet(self):
        self.total -= self.bet

# %%
def hit(deck,hand):
    hand.add_card(deck.dealone())

# %%
def hit_or_stand(deck,hand):
    global playing 
    hors=input('Hit or Stand?')
    if hors =='Hit':
        hit(deck, hand)
        print('c')
        show_some(player,dealer)
        playing=True
    else: 
        playing=False

# %%
def show_some(player,dealer):
    print('Dealers Hand:')
    print('First card is hidden')
    print(dealer.cards[1])
    print('Players Hand: ')
    for card in player.cards:
        print(card)
    
def show_all(player,dealer):
    print('Dealers Hand:')
    for card in dealer.cards:
        print(card)
    print('Players Hand: ')
    for card in player.cards:
        print(card)

# %%
def player_busts():
    print('Player loses')
    pchips.lose_bet()

def player_wins():
    print('Player wins')
    pchips.win_bet()

def dealer_busts():
    print('Player wins')
    pchips.win_bet()
    
def dealer_wins():
    print('Player loses')
    pchips.lose_bet()
    
def push():
    print('Its a tie')

# %%
print('Welcome to Blackjack!')
playing=True
while True:
    
    deck = Deck()
    deck.shuffle()
    player=Hand()
    player.add_card(deck.dealone())
    player.add_card(deck.dealone())
    dealer=Hand()
    dealer.add_card(deck.dealone())
    dealer.add_card(deck.dealone())
    pchips = Chips()
    show_some(player,dealer)


    while playing:
            hit_or_stand(deck, player)

    
    if player.value >21:
        player.adjust_for_ace()
    if player.value >21:
        show_all(player,dealer)
        player_busts()

    elif player.value<=21:
        while dealer.value <=17:
            
            hit(deck,dealer)
        show_all(player, dealer)
        if dealer.value>21:
            dealer.adjust_for_ace()
            if dealer.value<=21:
                pass
            else:
                dealer_busts()
            
        if dealer.value>player.value:
            dealer_wins()
        elif player.value>dealer.value:
            player_wins()
        else:
            push()
        
    
    print(f'Player has {pchips.total} remaining')
    
    playagain=input('Play again? Y or N')
    if playagain == 'N':
        break
    else:
        playing = True
        continue
# Out:
# Welcome to Blackjack!
# How many chips do you want to start with?100
# How much do you want to bet?20
# Dealers Hand:
# First card is hidden
# Queen of Clubs
# Players Hand:
# Jack of Spades
# Ace of Spades
# Hit or Stand?Stand
# Dealers Hand:
# Nine of Clubs
# Queen of Clubs
# Players Hand:
# Jack of Spades
# Ace of Spades
# Player wins
# Player has 140 remaining
# Play again? Y or NY
# How many chips do you want to start with?100
# How much do you want to bet?50
# Dealers Hand:
# First card is hidden
# King of Diamonds
# Players Hand:
# Three of Spades
# Three of Diamonds
# Hit or Stand?Hit
# c
# Dealers Hand:
# First card is hidden
# King of Diamonds
# Players Hand:
# Three of Spades
# Three of Diamonds
# Two of Diamonds
# Hit or Stand?Hit
# c
# Dealers Hand:
# First card is hidden
# King of Diamonds
# Players Hand:
# Three of Spades
# Three of Diamonds
# Two of Diamonds
# Seven of Diamonds
# Hit or Stand?Hit
# c
# Dealers Hand:
# First card is hidden
# King of Diamonds
# ...
